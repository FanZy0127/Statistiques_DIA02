# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
data = sns.load_dataset("mpg")
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars_per_origin = pd.crosstab(data['name'], data['origin'], margins=True)
cars_per_origin
# Out:
# origin                   europe  japan  usa  All
# name
# amc ambassador brougham       0      0    1    1
# amc ambassador dpl            0      0    1    1
# amc ambassador sst            0      0    1    1
# amc concord                   0      0    2    2
# amc concord d/l               0      0    1    1
# ...                         ...    ...  ...  ...
# vw pickup                     1      0    0    1
# vw rabbit                     2      0    0    2
# vw rabbit c (diesel)          1      0    0    1
# vw rabbit custom              1      0    0    1
# All                          70     79  249  398
#
# [306 rows x 4 columns]

# %%
cylinders_per_origin = pd.crosstab(data['origin'], data['cylinders'])
f, ax = plt.subplots(figsize=(12, 9))
cylinder_heatmap = sns.heatmap(cylinders_per_origin, cmap="YlGnBu", annot=True)

# %%
# f, ax = plt.subplots(figsize=(12, 9))
heatmap = sns.heatmap(data.corr(numeric_only=True), vmin=-1, vmax=1, annot=True)

# %%
# Exemple d'analyse de données complète par région

sns.set()
sns.pairplot(data, height=2.0, hue ='origin')
plt.show();
